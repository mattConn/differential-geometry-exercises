# %%
using Plots
using Calculus
pyplot()

r(t,a=0.7) = 1+a*cos(t)
x(t) = r(t)*cos(t)
y(t) = r(t)*sin(t)

COLOR = "black"
LW = 2.0

plot(x, y,0, 2pi,ticks=false,axis=false,label="",color=COLOR,linewidth=LW)
