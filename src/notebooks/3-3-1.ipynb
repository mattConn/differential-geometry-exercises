# %%
using Plots
using Calculus
pyplot()

p = 2
q = 3

x(t) = p*cos(t)
y(t) = q*sin(t)

COLOR = "black"
LW = 2.0
LABEL = ""
# Out:
# ""

# %%
xl(t) = x(pi/4)
yl(t) = t

plot(x, y,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)
plot!(xl, yl,y(-pi/4), y(pi/4),ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)

annotate!([(x(pi/4)+.1, y(pi/4)+.2, text("V",22))])
annotate!([(x(-pi/4)+.2, y(-pi/4)-.3, text("W",22))])

scatter!(
    [x(pi/4),x(-pi/4)],[y(pi/4),y(-pi/4)],
    color=COLOR,label=LABEL,marker = (6,6,stroke(0,:black,1.0)))

# %%
# xl(t) = 2*t
# yl(t) = t

# plot(x, y,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)

# plot!(xl, yl,y(-pi), y(pi)-1,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)

# scatter!(
#     [xl(-pi),x(-pi/4)],[y(pi),y(pi)+1],
#     color=COLOR,label=LABEL,marker = (8,8,stroke(0,:black,1.0)))

# %%
xl(t) = x(pi/4)
yl(t) = t

plot(x, y,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)

# %%
xl(t) = x(pi/4)
yl(t) = t

d(t) = q*(sin(-t) - sin(t))

# plot(x, y,0, 2pi,label=LABEL,color=COLOR,linewidth=LW)
plot(yl, d,0, pi,label=LABEL,color=COLOR,linewidth=LW)
# plot!(yl, d',0, pi,label=LABEL,color=COLOR,linewidth=LW)
# plot!(yl, d'',0, 2pi,label=LABEL,color=COLOR,linewidth=LW)

# %%
# x = a(3cos(t) - cos(3t)), y = a(3sin(t) - sin(3t)) 
xl(t) = x(pi/4)
yl(t) = t

ny(t) = 0.5*(5*cos(t) - cos(3*t))
nx(t) = 0.5*(5*sin(t) - sin(3*t))

plot(nx, ny,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)
