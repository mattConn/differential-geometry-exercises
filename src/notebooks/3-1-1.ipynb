# %%
using Plots
using Calculus
pyplot()

r(t) = 1+a*cos(t)
x(t) = r(t)*cos(t)
y(t) = r(t)*sin(t)

COLOR = "black"
LW = 2.0
LABEL = ""
# Out:
# ""

# %%
a = 0.7
plot(x, y,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)

# %%
a = 1
plot(x, y,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)

# %%
a = 2
plot(x, y,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)

# %%
a = 2
t0 = acos(-1/a)
t1 = 2pi-t0
plot(x, y,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)
# text(0, 0, "hello")
scatter!([x(t0)],[y(t0)], color="red",label=LABEL,)

# %%
a = 2
t0 = acos(-1/a)
t1 = 2pi-t0
plot(x, y,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)
scatter!(
    [x(t0)+.5,x(t0)+1.5,x(t0)-.2],[y(t0)],
    color="white",label=LABEL,series_annotations=["Int2","Int1","Ext"],marker = (0,0,stroke(0,:red,1.0)))

# %%
a = 2

f1(t) = -sin(t)-2*a*cos(t)*sin(t)
# f2(t) = cos(t)+a*(-sin(t)^2+cos(t)^2)
f2(t) = cos(t)+a*(cos(2t))

getnorm(x,y,t) = sqrt(x(t)^2+y(t)^2)

# unit tangent
n1(t) = getnorm(x',y',t)
ux1(t) = x'(t)/n(t)
uy1(t) = y'(t)/n(t)

xn(t) = x''(t) * (1/getnorm(x',y',t)) * (1/getnorm(x'',y'',t))
yn(t) = y''(t) * (1/getnorm(x',y',t)) * (1/getnorm(x'',y'',t))


plot(x, y,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)
# plot!(ux1,uy1,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)
plot!(xn,yn,0, 2pi,ticks=false,axis=false,label=LABEL,color=COLOR,linewidth=LW)
